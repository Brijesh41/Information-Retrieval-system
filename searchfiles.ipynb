# %%
from google.colab import files
uploaded = files.upload()
import pandas as pd
import io
df = pd.read_csv(io.StringIO(uploaded['ai.txt'].decode('utf-8')))
ai=df.to_string()
# Out:
#      <input type="file" id="files-da8de7dc-804b-4418-92f3-41d1a7d0ea13" name="files[]" multiple disabled />
#      <output id="result-da8de7dc-804b-4418-92f3-41d1a7d0ea13">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ai.txt to ai (1).txt

# %%
from google.colab import files
uploaded = files.upload()
import pandas as pd
import io
df = pd.read_csv(io.StringIO(uploaded['cc.txt'].decode('utf-8')))
cc=df.to_string()
# Out:
#      <input type="file" id="files-e2483e5d-8d2c-4dd2-a7b6-414b33718a30" name="files[]" multiple disabled />
#      <output id="result-e2483e5d-8d2c-4dd2-a7b6-414b33718a30">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cc.txt to cc (1).txt

# %%
searchwords="computing"
res = searchwords.split()
for k in res:
  print(k)
# Out:
# computing

# %%
listofiles = [ai,cc]
listofilei = ["ai.txt","cc.txt"]
ar = []
for x in listofiles:
  ar.append(x.split())

# %%
for x in ar:
  print(x)
# Out:
# ['Empty', 'DataFrame', 'Columns:', '[Artificial', 'intelligence', '(AI)', 'is', 'the', 'simulation', 'of', 'human', 'intelligence', 'processes', 'by', 'machines,', 'especially', 'computer', 'systems.', 'These', 'processes', 'include', 'learning', '(the', 'acquisition', 'of', 'information', 'and', 'rules', 'for', 'using', 'the', 'information),', 'reasoning', '(using', 'rules', 'to', 'reach', 'approximate', 'or', 'definite', 'conclusions)', 'and', 'self-correction.]', 'Index:', '[]']
# ['Empty', 'DataFrame', 'Columns:', '[Cognitive', 'computing', 'describes', 'technologies', 'that', 'are', 'based', 'on', 'the', 'scientific', 'principles', 'behind', 'artificial', 'intelligence', 'and', 'signal', 'processing,', 'encompassing', 'machine', 'self-learning,', 'human-computer', 'interaction,', 'natural', 'language', 'processing,', 'data', 'mining', 'and', 'more.]', 'Index:', '[]']

# %%
index=[]
number=0
for x in ar:
  for y in x:
    for z in res:
      
      
      if( z== y):
        print(x)
        index.append(number)
        print(number)
        break
# Out:
# ['Empty', 'DataFrame', 'Columns:', '[Cognitive', 'computing', 'describes', 'technologies', 'that', 'are', 'based', 'on', 'the', 'scientific', 'principles', 'behind', 'artificial', 'intelligence', 'and', 'signal', 'processing,', 'encompassing', 'machine', 'self-learning,', 'human-computer', 'interaction,', 'natural', 'language', 'processing,', 'data', 'mining', 'and', 'more.]', 'Index:', '[]']
# 0

# %%
remove=['Empty','DataFrame','Columns']
wordcount={}
for x in ar:
  for word in x:
    
    
    if word not in wordcount:
      wordcount[word] = 1
    else:
      wordcount[word] += 1

for word in wordcount:
  if word in remove:
    wordcount[word]=0

# %%
print(wordcount)
# Out:
# {'Empty': 0, 'DataFrame': 0, 'Columns:': 2, '[Artificial': 1, 'intelligence': 3, '(AI)': 1, 'is': 1, 'the': 3, 'simulation': 1, 'of': 2, 'human': 1, 'processes': 2, 'by': 1, 'machines,': 1, 'especially': 1, 'computer': 1, 'systems.': 1, 'These': 1, 'include': 1, 'learning': 1, '(the': 1, 'acquisition': 1, 'information': 1, 'and': 4, 'rules': 2, 'for': 1, 'using': 1, 'information),': 1, 'reasoning': 1, '(using': 1, 'to': 1, 'reach': 1, 'approximate': 1, 'or': 1, 'definite': 1, 'conclusions)': 1, 'self-correction.]': 1, 'Index:': 2, '[]': 2, '[Cognitive': 1, 'computing': 1, 'describes': 1, 'technologies': 1, 'that': 1, 'are': 1, 'based': 1, 'on': 1, 'scientific': 1, 'principles': 1, 'behind': 1, 'artificial': 1, 'signal': 1, 'processing,': 2, 'encompassing': 1, 'machine': 1, 'self-learning,': 1, 'human-computer': 1, 'interaction,': 1, 'natural': 1, 'language': 1, 'data': 1, 'mining': 1, 'more.]': 1}

# %%
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt



counts = dict(Counter(wordcount).most_common(10))

labels, values = zip(*counts.items())

# sort your values in descending order
indSort = np.argsort(values)[::-1]

# rearrange your data
labels = np.array(labels)[indSort]
values = np.array(values)[indSort]

indexes = np.arange(len(labels))

bar_width = 10

plt.bar(indexes, values)

# add labels
plt.xticks(indexes + bar_width, labels)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
comment_words=''
stopwords = set(STOPWORDS)

for words in ar:
  for y in words:
    comment_words = comment_words + y + ' '
  

wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()
